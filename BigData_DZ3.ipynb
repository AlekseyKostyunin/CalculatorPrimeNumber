# %% [markdown]
# <a href="https://colab.research.google.com/github/AlekseyKostyunin/CalculatorPrimeNumber/blob/master/BigData_DZ3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
# Загружаем данные о погоде в разных городах
cities = ['Moskau', 'Paris', 'London']
data = []
for city in cities:
    response = requests.get(f'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=4c4f373133dd440c860130952240609&q={city}&format=json&date=2024-08-01&enddate=2024-09-05')
    data.append(response.json())

# %%
for i in range(0, 3):
  print(data[i])
# Out:
# {'data': {'request': [{'type': 'City', 'query': 'Moskau, Russia'}], 'weather': [{'date': '2024-08-01', 'astronomy': [{'sunrise': '04:35 AM', 'sunset': '08:35 PM', 'moonrise': '12:06 AM', 'moonset': '07:47 PM', 'moon_phase': 'Waning Crescent', 'moon_illumination': '16'}], 'maxtempC': '20', 'maxtempF': '68', 'mintempC': '14', 'mintempF': '57', 'avgtempC': '16', 'avgtempF': '62', 'totalSnow_cm': '0.0', 'sunHour': '13.0', 'uvIndex': '5', 'hourly': [{'time': '0', 'tempC': '14', 'tempF': '57', 'windspeedMiles': '6', 'windspeedKmph': '10', 'winddirDegree': '281', 'winddir16Point': 'W', 'weatherCode': '116', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}], 'weatherDesc': [{'value': 'Partly cloudy'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '90', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1003', 'pressureInches': '30', 'cloudcover': '42', 'HeatIndexC': '14', 'HeatIndexF': '57', 'DewPointC': '13', 'DewPointF': '55', 'WindChillC': '14', 'WindChillF': '56', 'WindGustMiles': '10', 'WindGustKmph': '16', 'FeelsLikeC': '14', 'FeelsLikeF': '56', 'uvIndex': '1'}, {'time': '300', 'tempC': '15', 'tempF': '58', 'windspeedMiles': '7', 'windspeedKmph': '11', 'winddirDegree': '277', 'winddir16Point': 'W', 'weatherCode': '119', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}], 'weatherDesc': [{'value': 'Cloudy'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '86', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1003', 'pressureInches': '30', 'cloudcover': '70', 'HeatIndexC': '15', 'HeatIndexF': '58', 'DewPointC': '12', 'DewPointF': '54', 'WindChillC': '14', 'WindChillF': '57', 'WindGustMiles': '11', 'WindGustKmph': '17', 'FeelsLikeC': '14', 'FeelsLikeF': '57', 'uvIndex': '1'}, {'time': '600', 'tempC': '14', 'tempF': '58', 'windspeedMiles': '7', 'windspeedKmph': '11', 'winddirDegree': '254', 'winddir16Point': 'WSW', 'weatherCode': '116', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}], 'weatherDesc': [{'value': 'Partly cloudy'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '84', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1003', 'pressureInches': '30', 'cloudcover': '35', 'HeatIndexC': '14', 'HeatIndexF': '58', 'DewPointC': '12', 'DewPointF': '53', 'WindChillC': '14', 'WindChillF': '57', 'WindGustMiles': '10', 'WindGustKmph': '16', 'FeelsLikeC': '14', 'FeelsLikeF': '57', 'uvIndex': '4'}, {'time': '900', 'tempC': '18', 'tempF': '65', 'windspeedMiles': '9', 'windspeedKmph': '14', 'winddirDegree': '253', 'winddir16Point': 'WSW', 'weatherCode': '113', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}], 'weatherDesc': [{'value': 'Sunny'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '65', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1002', 'pressureInches': '30', 'cloudcover': '18', 'HeatIndexC': '18', 'HeatIndexF': '65', 'DewPointC': '12', 'DewPointF': '53', 'WindChillC': '18', 'WindChillF': '65', 'WindGustMiles': '10', 'WindGustKmph': '16', 'FeelsLikeC': '18', 'FeelsLikeF': '65', 'uvIndex': '5'}, {'time': '1200', 'tempC': '18', 'tempF': '65', 'windspeedMiles': '10', 'windspeedKmph': '16', 'winddirDegree': '267', 'winddir16Point': 'W', 'weatherCode': '353', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}], 'weatherDesc': [{'value': 'Light rain shower'}], 'precipMM': '0.9', 'precipInches': '0.0', 'humidity': '76', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1001', 'pressureInches': '30', 'cloudcover': '58', 'HeatIndexC': '18', 'HeatIndexF': '65', 'DewPointC': '14', 'DewPointF': '58', 'WindChillC': '18', 'WindChillF': '65', 'WindGustMiles': '15', 'WindGustKmph': '25', 'FeelsLikeC': '18', ' ...
# {'data': {'request': [{'type': 'City', 'query': 'Paris, France'}], 'weather': [{'date': '2024-08-01', 'astronomy': [{'sunrise': '06:24 AM', 'sunset': '09:29 PM', 'moonrise': '02:31 AM', 'moonset': '08:15 PM', 'moon_phase': 'Waning Crescent', 'moon_illumination':
 'windspeedMiles': '5', 'windspeedKmph': '8', 'winddirDegree': '60', 'winddir16Point': 'ENE', 'weatherCode': '116', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}], 'weatherDesc': [{'value': 'Partly cloudy'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '65', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1014', 'pressureInches': '30', 'cloudcover': '44', 'HeatIndexC': '20', 'HeatIndexF': '67', 'DewPointC': '13', 'DewPointF': '55', 'WindChillC': '20', 'WindChillF': '67', 'WindGustMiles': '7', 'WindGustKmph': '11', 'FeelsLikeC': '20', 'FeelsLikeF': '67', 'uvIndex': '1'}, {'time': '300', 'tempC': '18', 'tempF': '65', 'windspeedMiles': '4', 'windspeedKmph': '6', 'winddirDegree': '53', 'winddir16Point': 'NE', 'weatherCode': '113', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}], 'weatherDesc': [{'value': 'Clear'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '70', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1013', 'pressureInches': '30', 'cloudcover': '14', 'HeatIndexC': '18', 'HeatIndexF': '65', 'DewPointC': '13', 'DewPointF': '55', 'WindChillC': '18', 'WindChillF': '65', 'WindGustMiles': '5', 'WindGustKmph': '9', 'FeelsLikeC': '18', 'FeelsLikeF': '65', 'uvIndex': '1'}, {'time': '600', 'tempC': '19', 'tempF': '66', 'windspeedMiles': '3', 'windspeedKmph': '5', 'winddirDegree': '39', 'winddir16Point': 'NE', 'weatherCode': '113', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}], 'weatherDesc': [{'value': 'Sunny'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '72', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1013', 'pressureInches': '30', 'cloudcover': '22', 'HeatIndexC': '19', 'HeatIndexF': '66', 'DewPointC': '14', 'DewPointF': '57', 'WindChillC': '19', 'WindChillF': '66', 'WindGustMiles': '4', 'WindGustKmph': '7', 'FeelsLikeC': '19', 'FeelsLikeF': '66', 'uvIndex': '5'}, {'time': '900', 'tempC': '23', 'tempF': '73', 'windspeedMiles': '5', 'windspeedKmph': '8', 'winddirDegree': '24', 'winddir16Point': 'NNE', 'weatherCode': '116', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}], 'weatherDesc': [{'value': 'Partly cloudy'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '62', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1013', 'pressureInches': '30', 'cloudcover': '33', 'HeatIndexC': '25', 'HeatIndexF': '77', 'DewPointC': '15', 'DewPointF': '60', 'WindChillC': '23', 'WindChillF': '73', 'WindGustMiles': '6', 'WindGustKmph': '10', 'FeelsLikeC': '25', 'FeelsLikeF': '77', 'uvIndex': '6'}, {'time': '1200', 'tempC': '27', 'tempF': '81', 'windspeedMiles': '5', 'windspeedKmph': '8', 'winddirDegree': '27', 'winddir16Point': 'NNE', 'weatherCode': '176', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}], 'weatherDesc': [{'value': 'Patchy rain possible'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '50', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1013', 'pressureInches': '30', 'cloudcover': '54', 'HeatIndexC': '28', 'HeatIndexF': '82', 'DewPointC': '16', 'DewPointF': '60', 'WindChillC': '27', 'WindChillF': '81', 'WindGustMiles': '5', 'WindGustKmph': '9', 'FeelsLikeC': '28', 'F ...

# %%
print(len(data[0]['data']['weather']))
# Out:
# 35

# %%
print(data[0]['data']['weather'][0]['maxtempC'])
# Out:
# 20

# %%
print(data[0]['data']['weather'][0]['date'])
# Out:
# 2024-08-01

# %%
# Создаем график изменения температуры в разных городах
l = len(data[i]['data']['weather'])
x = [[0] * l] * 3
y = [[0] * l] * 3
for i in range(3):
  r1 = [0] * l
  r2 = [0] * l
  for z in range(l):
    r1[z] = data[i]['data']['weather'][z]['date']
    r2[z] = int(data[i]['data']['weather'][z]['maxtempC'])
  x[i] = r1
  y[i] = r2
plt.figure(figsize=(50, 10))
fig, ax = plt.subplots()
ax.plot(x[0], y[0], label='Moskau')
ax.plot(x[1], y[1], label='Paris')
ax.plot(x[2], y[2], label='London')
ax.legend(loc='lower right')
ax.tick_params(axis='x', labelrotation = 90)
plt.title('Температура в городах')
plt.show()
